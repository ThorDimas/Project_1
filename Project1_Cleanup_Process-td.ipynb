# %% [markdown]
# Questions that need to be answered:
# * Where did the biggest meteorites land?
# * Which year did the most meteorites land on Earth?
# * Which is the most common type of meteorite?
# * Which is the least common type?

# %%
#Import dependencies
import pandas as pd
import numpy as np
import os 
import csv 

import requests
import json

# %%
# #import from API
url = "https://data.nasa.gov/resource/gh4g-9sfh.json"
meteorite_data = requests.get(url).json()
meteorite_data_df = pd.DataFrame(meteorite_data)
meteorite_data_df.head()
# Out:
#        name   id nametype     recclass    mass  fall                     year  \
# 0    Aachen    1    Valid           L5      21  Fell  1880-01-01T00:00:00.000
# 1    Aarhus    2    Valid           H6     720  Fell  1951-01-01T00:00:00.000
# 2      Abee    6    Valid          EH4  107000  Fell  1952-01-01T00:00:00.000
# 3  Acapulco   10    Valid  Acapulcoite    1914  Fell  1976-01-01T00:00:00.000
# 4   Achiras  370    Valid           L6     780  Fell  1902-01-01T00:00:00.000
#
#        reclat      reclong                                        geolocation  \
# 0   50.775000     6.083330     {'latitude': '50.775', 'longitude': '6.08333'}
# 1   56.183330    10.233330  {'latitude': '56.18333', 'longitude': '10.23333'}
# 2   54.216670  -113.000000    {'latitude': '54.21667', 'longitude': '-113.0'}
# 3   16.883330   -99.900000     {'latitude': '16.88333', 'longitude': '-99.9'}
# 4  -33.166670   -64.950000   {'latitude': '-33.16667', 'longitude': '-64.95'}
#
# ...

# %%
#Import data files or API
source_data_path = os.path.join("./Meteorite_Landings.csv")
data_file_read = pd.read_csv(source_data_path)

# %%
#Create data frame and print 
meteorite_df = pd.DataFrame(data_file_read)
meteorite_df
# Out:
#                      name     id nametype      recclass  mass (g)   fall  \
# 0              Zulu Queen  30414    Valid          L3.7     200.0  Found
# 1                  Aarhus      2    Valid            H6     720.0   Fell
# 2                    Abee      6    Valid           EH4  107000.0   Fell
# 3                Acapulco     10    Valid   Acapulcoite    1914.0   Fell
# 4                 Achiras    370    Valid            L6     780.0   Fell
# ...                   ...    ...      ...           ...       ...    ...
# 45711  Miller Range 05110  45810   Relict  Fusion crust       0.1  Found
# 45712      Österplana 031  44831   Relict     Relict OC       NaN  Found
# 45713      Österplana 032  44832   Relict     Relict OC       NaN  Found
# 45714      Österplana 033  44833   Relict     Relict OC       NaN  Found
# 45715      Österplana 034  44834   Relict     Relict OC       NaN  Found
#
#          year    reclat    reclong             GeoLocation  States  Counties
# ...

# %%
#Clean all data with no values
# we drop states and counties because they weren´t relevant
clean_meteorite_df = meteorite_df.drop(columns = ["States", "Counties"])
clean_meteorite_df

# %%
# we will clean GeoLocation, we will drop NaN
clean_meteorite_df_2 = clean_meteorite_df.dropna(subset=["GeoLocation"])
clean_meteorite_df_2

# %%
#Export clean data for analysis
# clean_meteorite_df_2.to_csv('cleaned_meteorite.csv', index=False)
