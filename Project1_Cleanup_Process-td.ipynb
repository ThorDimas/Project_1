# %% [markdown]
# Questions that need to be answered:
# * Where did the biggest meteorites land?
# * Which year did the most meteorites land on Earth?
# * Which is the most common type of meteorite?
# * Which is the least common type?

# %%
#Import dependencies
import pandas as pd
import numpy as np
import os 
import csv

# %%
#Import data files or API
source_data_path = os.path.join("./Meteorite_Landings.csv")
data_file_read = pd.read_csv(source_data_path)

# %%
#Create data frame and print 
meteorite_df = pd.DataFrame(data_file_read)
meteorite_df
# Out:
#                      name     id nametype      recclass  mass (g)   fall  \
# 0              Zulu Queen  30414    Valid          L3.7     200.0  Found
# 1                  Aarhus      2    Valid            H6     720.0   Fell
# 2                    Abee      6    Valid           EH4  107000.0   Fell
# 3                Acapulco     10    Valid   Acapulcoite    1914.0   Fell
# 4                 Achiras    370    Valid            L6     780.0   Fell
# ...                   ...    ...      ...           ...       ...    ...
# 45711  Miller Range 05110  45810   Relict  Fusion crust       0.1  Found
# 45712      Österplana 031  44831   Relict     Relict OC       NaN  Found
# 45713      Österplana 032  44832   Relict     Relict OC       NaN  Found
# 45714      Österplana 033  44833   Relict     Relict OC       NaN  Found
# 45715      Österplana 034  44834   Relict     Relict OC       NaN  Found
#
#          year    reclat    reclong             GeoLocation  States  Counties
# 0      1976.0  33.98333 -115.68333  (33.98333, -115.68333)     8.0    1177.0
# 1      1951.0  56.18333   10.23333    (56.18333, 10.23333)     NaN       NaN
# 2      1952.0  54.21667 -113.00000      (54.21667, -113.0)     NaN       NaN
# 3      1976.0  16.88333  -99.90000       (16.88333, -99.9)     NaN       NaN
# 4      1902.0 -33.16667  -64.95000     (-33.16667, -64.95)     NaN       NaN
# ...       ...       ...        ...                     ...     ...       ...
# 45711  2005.0       NaN        NaN                     NaN     NaN       NaN
# 45712  1998.0  58.58333   13.43333    (58.58333, 13.43333)     NaN       NaN
# 45713  2000.0  58.58333   13.43333    (58.58333, 13.43333)     NaN       NaN
# 45714  2000.0  58.58333   13.43333    (58.58333, 13.43333)     NaN       NaN
# 45715  1998.0  58.58333   13.43333    (58.58333, 13.43333)     NaN       NaN
#
# [45716 rows x 12 columns]

# %%
#Clean all data with no values
# we drop states and counties because they weren´t relevant
clean_meteorite_df = meteorite_df.drop(columns = ["States","GeoLocation", "Counties"])
clean_meteorite_df
# Out:
#                      name     id nametype      recclass  mass (g)   fall  \
# 0              Zulu Queen  30414    Valid          L3.7     200.0  Found
# 1                  Aarhus      2    Valid            H6     720.0   Fell
# 2                    Abee      6    Valid           EH4  107000.0   Fell
# 3                Acapulco     10    Valid   Acapulcoite    1914.0   Fell
# 4                 Achiras    370    Valid            L6     780.0   Fell
# ...                   ...    ...      ...           ...       ...    ...
# 45711  Miller Range 05110  45810   Relict  Fusion crust       0.1  Found
# 45712      Österplana 031  44831   Relict     Relict OC       NaN  Found
# 45713      Österplana 032  44832   Relict     Relict OC       NaN  Found
# 45714      Österplana 033  44833   Relict     Relict OC       NaN  Found
# 45715      Österplana 034  44834   Relict     Relict OC       NaN  Found
#
#          year    reclat    reclong
# 0      1976.0  33.98333 -115.68333
# 1      1951.0  56.18333   10.23333
# 2      1952.0  54.21667 -113.00000
# 3      1976.0  16.88333  -99.90000
# 4      1902.0 -33.16667  -64.95000
# ...       ...       ...        ...
# 45711  2005.0       NaN        NaN
# 45712  1998.0  58.58333   13.43333
# 45713  2000.0  58.58333   13.43333
# 45714  2000.0  58.58333   13.43333
# 45715  1998.0  58.58333   13.43333
#
# [45716 rows x 9 columns]

# %%
# we will clean GeoLocation, we will drop NaN
clean_meteorite_df_2 = clean_meteorite_df.dropna(subset=["reclat", "mass (g)", "reclong"])
clean_meteorite_df_2
# Out:
#                       name     id nametype                recclass  mass (g)  \
# 0               Zulu Queen  30414    Valid                    L3.7     200.0
# 1                   Aarhus      2    Valid                      H6     720.0
# 2                     Abee      6    Valid                     EH4  107000.0
# 3                 Acapulco     10    Valid             Acapulcoite    1914.0
# 4                  Achiras    370    Valid                      L6     780.0
# ...                    ...    ...      ...                     ...       ...
# 45674       Österplana 061  56160   Relict               Relict OC       0.0
# 45675       Österplana 062  56161   Relict               Relict OC       0.0
# 45676       Österplana 063  56162   Relict               Relict OC       0.0
# 45677       Österplana 064  56163   Relict               Relict OC       0.0
# 45686  David Glacier 92308   6614   Relict  Chondrite-fusion crust       1.7
#
#         fall    year    reclat    reclong
# 0      Found  1976.0  33.98333 -115.68333
# 1       Fell  1951.0  56.18333   10.23333
# 2       Fell  1952.0  54.21667 -113.00000
# 3       Fell  1976.0  16.88333  -99.90000
# 4       Fell  1902.0 -33.16667  -64.95000
# ...      ...     ...       ...        ...
# 45674  Found  2009.0  58.58333   13.43333
# 45675  Found  2010.0  58.58333   13.43333
# 45676  Found  2010.0  58.58333   13.43333
# 45677  Found  2011.0  58.58333   13.43333
# 45686  Found  1992.0 -75.31667  162.00000
#
# [38282 rows x 9 columns]

# %%
#redefine year type
clean_meteorite_df_2.dropna(subset=["year"], inplace=True)
clean_meteorite_df_2["year"] = clean_meteorite_df_2['year'].astype(int)
clean_meteorite_df_3 = clean_meteorite_df_2.sort_values(by="year")
clean_meteorite_df_3
# Out:
# C:\Users\thord\anaconda3\envs\Pythondata\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# C:\Users\thord\anaconda3\envs\Pythondata\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                         name     id nametype      recclass    mass (g)   fall  \
# 704                   Nogata  16988    Valid            L6       472.0   Fell
# 278                  Elbogen   7823    Valid     Iron, IID    107000.0   Fell
# 856         Rivolta de Bassi  22614    Valid    Stone-uncl       103.3   Fell
# 283                Ensisheim  10039    Valid           LL6    127000.0   Fell
# 5439         Campo del Cielo   5247    Valid  Iron, IAB-MG  50000000.0  Found
# ...                      ...    ...      ...           ...         ...    ...
# 30840  Northwest Africa 7857  57422    Valid           LL6       246.0  Found
# 30843  Northwest Africa 7861  57425    Valid            L5       611.0  Found
# 30845  Northwest Africa 7863  57427    Valid           LL5      1000.0  Found
# 30841  Northwest Africa 7858  57423    Valid            H4       459.0  Found
# 30746  Northwest Africa 7701  57150    Valid           CK6        55.0  Found
#
#        year    reclat    reclong
# 704     860  33.72500  130.75000
# 278    1399  50.18333   12.73333
# 856    1490  45.48333    9.51667
# 283    1491  47.86667    7.35000
# 5439   1575 -27.46667  -60.58333
# ...     ...       ...        ...
# 30840  2013   0.00000    0.00000
# 30843  2013   0.00000    0.00000
# 30845  2013   0.00000    0.00000
# 30841  2013   0.00000    0.00000
# 30746  2101   0.00000    0.00000
#
# [38115 rows x 9 columns]

# %%
#sort meteorites that fall before 2023 but after 1960
new_era_df = clean_meteorite_df_3.loc[(clean_meteorite_df_3["year"] >= 1960) & (clean_meteorite_df_3["year"] < 2023)]
new_era_df
# Out:
#                         name     id nametype recclass  mass (g)   fall  year  \
# 3475             as-Su'aydan   2354    Valid       L5    5855.0  Found  1960
# 934                  Soheria  23660    Valid       OC      72.9   Fell  1960
# 38215                  Venus  24160    Valid       H4    1013.0  Found  1960
# 24154                Midland  16633    Valid     Iron      34.0  Found  1960
# 38131               Um Habib  24111    Valid       L6     696.0  Found  1960
# ...                      ...    ...      ...      ...       ...    ...   ...
# 30839  Northwest Africa 7856  57421    Valid      LL6     517.0  Found  2013
# 30840  Northwest Africa 7857  57422    Valid      LL6     246.0  Found  2013
# 30843  Northwest Africa 7861  57425    Valid       L5     611.0  Found  2013
# 30845  Northwest Africa 7863  57427    Valid      LL5    1000.0  Found  2013
# 30841  Northwest Africa 7858  57423    Valid       H4     459.0  Found  2013
#
#          reclat   reclong
# 3475   21.25417  55.30500
# 934    27.13333  84.06667
# 38215  32.40000 -97.08333
# 24154  44.75000 -79.88333
# 38131  21.50000  50.50000
# ...         ...       ...
# 30839   0.00000   0.00000
# 30840   0.00000   0.00000
# 30843   0.00000   0.00000
# 30845   0.00000   0.00000
# 30841   0.00000   0.00000
#
# [36277 rows x 9 columns]

# %%
#Group the recclass
new_era_df.replace(to_replace=['Acapulcoite', 'Acapulcoite/Lodranite', 'Acapulcoite/lodranite','Lodranite','Lodranitean','Winonaite','Achondrite-prim'], value="PA", inplace=True)

new_era_df.replace(to_replace= ['Angrite', 'Aubrite','Aubrite-an','Ureilite', 'Ureilite-an','Ureilite-pmict',
           'Brachinite','Diogenite', 'Diogenite-an', 'Diogenite-olivine', 'Diogenite-pm',
           'Eucrite', 'Eucrite-Mg rich', 'Eucrite-an', 'Eucrite-br','Eucrite-cm',
           'Eucrite-mmict', 'Eucrite-pmict', 'Eucrite-unbr','Howardite'], value= "AA", inplace = True)

new_era_df.replace(to_replace= ['Lunar', 'Lunar (anorth)', 'Lunar (bas. breccia)',
           'Lunar (bas/anor)', 'Lunar (bas/gab brec)', 'Lunar (basalt)',
           'Lunar (feldsp. breccia)', 'Lunar (gabbro)', 'Lunar (norite)'], value= "L", inplace = True)

new_era_df.replace(to_replace= ['Martian', 'Martian (OPX)','Martian (chassignite)', 'Martian (nakhlite)',
           'Martian (shergottite)','Martian (basaltic breccia)'], value= "M", inplace = True)

new_era_df.replace(to_replace= ['C','C2','C4','C4/5','C6','C1-ung', 'C1/2-ung','C2-ung',
           'C3-ung', 'C3/4-ung','C4-ung','C5/6-ung',
           'CB', 'CBa', 'CBb', 'CH/CBb', 'CH3', 'CH3 ', 'CI1', 'CK', 'CK3',
           'CK3-an', 'CK3.8', 'CK3/4', 'CK4', 'CK4-an', 'CK4/5', 'CK5',
           'CK5/6', 'CK6', 'CM', 'CM-an', 'CM1', 'CM1/2', 'CM2', 'CM2-an',
           'CO3', 'CO3 ', 'CO3.0', 'CO3.1', 'CO3.2', 'CO3.3', 'CO3.4', 'CO3.5',
           'CO3.6', 'CO3.7', 'CO3.8', 'CR', 'CR-an', 'CR1', 'CR2', 'CR2-an',
           'CV2', 'CV3', 'CV3-an','CR7'], value= "CC", inplace = True)

new_era_df.replace(to_replace= ['OC', 'OC3','H', 'H(5?)', 'H(?)4', 'H(L)3', 'H(L)3-an', 'H-an','H-imp melt',
           'H-melt rock', 'H-metal', 'H/L3', 'H/L3-4', 'H/L3.5',
           'H/L3.6', 'H/L3.7', 'H/L3.9', 'H/L4', 'H/L4-5', 'H/L4/5', 'H/L5',
           'H/L6', 'H/L6-melt rock', 'H/L~4', 'H3', 'H3 ', 'H3-4', 'H3-5',
           'H3-6', 'H3-an', 'H3.0', 'H3.0-3.4', 'H3.1', 'H3.10', 'H3.2',
           'H3.2-3.7', 'H3.2-6', 'H3.2-an', 'H3.3', 'H3.4', 'H3.4-5',
           'H3.4/3.5', 'H3.5', 'H3.5-4', 'H3.6', 'H3.6-6', 'H3.7', 'H3.7-5',
           'H3.7-6', 'H3.7/3.8', 'H3.8', 'H3.8-4', 'H3.8-5', 'H3.8-6',
           'H3.8-an', 'H3.8/3.9', 'H3.8/4', 'H3.9', 'H3.9-5', 'H3.9-6',
           'H3.9/4', 'H3/4', 'H4', 'H4 ', 'H4(?)', 'H4-5', 'H4-6', 'H4-an',
           'H4/5', 'H4/6', 'H5', 'H5 ', 'H5-6', 'H5-7', 'H5-an',
           'H5-melt breccia', 'H5/6', 'H6', 'H6 ', 'H6-melt breccia', 'H6/7',
           'H7', 'H?','H~4', 'H~4/5', 'H~5', 'H~6','L', 'L(?)3',
           'L(H)3', 'L(LL)3', 'L(LL)3.05', 'L(LL)3.5-3.7', 'L(LL)5', 'L(LL)6',
           'L(LL)~4', 'L-imp melt', 'L-melt breccia', 'L-melt rock', 'L-metal',
           'L/LL', 'L/LL(?)3', 'L/LL-melt rock', 'L/LL3', 'L/LL3-5', 'L/LL3-6',
           'L/LL3.10', 'L/LL3.2', 'L/LL3.4', 'L/LL3.5', 'L/LL3.6/3.7', 'L/LL4',
           'L/LL4-6', 'L/LL4/5', 'L/LL5', 'L/LL5-6', 'L/LL5/6', 'L/LL6',
           'L/LL6-an', 'L/LL~4', 'L/LL~5', 'L/LL~6', 'L3', 'L3-4', 'L3-5',
           'L3-6', 'L3-7', 'L3.0', 'L3.0-3.7', 'L3.0-3.9', 'L3.05', 'L3.1',
           'L3.10', 'L3.2', 'L3.2-3.5', 'L3.2-3.6', 'L3.3', 'L3.3-3.5',
           'L3.3-3.6', 'L3.3-3.7', 'L3.4', 'L3.4-3.7', 'L3.5', 'L3.5-3.7',
           'L3.5-3.8', 'L3.5-3.9', 'L3.5-5', 'L3.6', 'L3.6-4', 'L3.7',
           'L3.7-3.9', 'L3.7-4', 'L3.7-6', 'L3.7/3.8', 'L3.8', 'L3.8-5',
           'L3.8-6', 'L3.8-an', 'L3.9', 'L3.9-5', 'L3.9-6', 'L3.9/4', 'L3/4',
           'L4', 'L4 ', 'L4-5', 'L4-6', 'L4-an', 'L4-melt rock', 'L4/5', 'L5',
           'L5 ', 'L5-6', 'L5-7', 'L5/6', 'L6', 'L6 ', 'L6-melt breccia',
           'L6-melt rock', 'L6/7', 'L7', 'LL', 'LL(L)3', 'LL-melt rock', 'LL3',
           'LL3-4', 'LL3-5', 'LL3-6', 'LL3.0', 'LL3.00', 'LL3.1', 'LL3.1-3.5',
           'LL3.10', 'LL3.15', 'LL3.2', 'LL3.3', 'LL3.4', 'LL3.5', 'LL3.6',
           'LL3.7', 'LL3.7-6', 'LL3.8', 'LL3.8-6', 'LL3.9', 'LL3.9/4', 'LL3/4',
           'LL4', 'LL4-5', 'LL4-6', 'LL4/5', 'LL4/6', 'LL5', 'LL5-6', 'LL5-7',
           'LL5/6', 'LL6', 'LL6 ', 'LL6(?)', 'LL6/7', 'LL7', 'LL7(?)',
           'LL<3.5', 'LL~3', 'LL~4', 'LL~4/5', 'LL~5', 'LL~6',
           'L~3', 'L~4', 'L~5', 'L~6','Relict H','Relict OC','LL-melt breccia','H-melt breccia',
                                 'L5-melt breccia','LL-imp melt','H3.05','LL6-melt breccia',
                                 'LL3.05','H4-melt breccia','LL3.8-4','L3.00','L~4-6','LL6-an',
                                 'L4-melt breccia','LL(L)3.1','L3-melt breccia','H3.15'], value= "OC", inplace = True)

new_era_df.replace(to_replace= ['EH','EH-imp melt', 'EH3', 'EH3/4-an', 'EH4', 'EH4/5', 'EH5', 'EH6',
           'EH6-an', 'EH7', 'EH7-an', 'EL3', 'EL3/4', 'EL4', 'EL4/5', 'EL5',
           'EL6', 'EL6 ', 'EL6/7', 'EL7','E','E3','E4', 'E5','E6','EL-melt rock'], value= "EC", inplace = True)

new_era_df.replace(to_replace= ['K', 'K3','R', 'R3', 'R3-4', 'R3-5', 'R3-6', 'R3.4', 'R3.5-6',
           'R3.6', 'R3.7', 'R3.8', 'R3.8-5', 'R3.8-6', 'R3.9', 'R3/4', 'R4',
           'R4/5', 'R5', 'R6','R3.5-4'], value= "AOC", inplace = True)

new_era_df.replace(to_replace= ['Pallasite', 'Pallasite, PES','Pallasite, PMG',
           'Pallasite, PMG-an', 'Pallasite, ungrouped',
           'Pallasite?'], value= "P", inplace = True)

new_era_df.replace(to_replace= ['Mesosiderite', 'Mesosiderite-A','Mesosiderite-A1',
           'Mesosiderite-A2', 'Mesosiderite-A3','Mesosiderite-A3/4',
           'Mesosiderite-A4', 'Mesosiderite-B','Mesosiderite-B1',
           'Mesosiderite-B2', 'Mesosiderite-B4','Mesosiderite-C',
           'Mesosiderite-C2', 'Mesosiderite-an','Mesosiderite?'], value= "MG", inplace = True)

new_era_df.replace(to_replace= ['Iron, IC', 'Iron, IC-an', 'Iron, IIAB', 'Iron, IIAB-an',
           'Iron, IIC', 'Iron, IID', 'Iron, IID-an','Iron, IIF', 'Iron, IIG',
           'Iron, IIIAB', 'Iron, IIIAB-an', 'Iron, IIIAB?', 'Iron, IIIE',
           'Iron, IIIE-an', 'Iron, IIIF', 'Iron, IVA', 'Iron, IVA-an',
           'Iron, IVB'], value= "MIM", inplace = True)

new_era_df.replace(to_replace= ['Iron, IAB complex', 'Iron, IAB-MG','Iron, IAB-an', 'Iron, IAB-sHH',
           'Iron, IAB-sHL', 'Iron, IAB-sLH','Iron, IAB-sLL', 'Iron, IAB-sLM',
           'Iron, IAB-ung', 'Iron, IAB?','Iron, IIE',
           'Iron, IIE-an', 'Iron, IIE?'], value= "NMIM", inplace = True)

new_era_df.replace(to_replace= ['Iron','Iron?','Relict iron','Chondrite-fusion crust',
           'Fusion crust','Impact melt breccia',
           'Enst achon-ung','Iron, ungrouped','Stone-uncl', 'Stone-ung',
           'Unknown','Achondrite-ung','Chondrite-ung',
           'Enst achon','E-an',  'E3-an',  'E5-an','Howardite-an','C3.0-ung','Iron, IAB-sHL-an'], value= "UN", inplace = True)

new_era_df
# Out:
# C:\Users\thord\anaconda3\envs\Pythondata\lib\site-packages\pandas\core\frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
#                         name     id nametype recclass  mass (g)   fall  year  \
# 3475             as-Su'aydan   2354    Valid       OC    5855.0  Found  1960
# 934                  Soheria  23660    Valid       OC      72.9   Fell  1960
# 38215                  Venus  24160    Valid       OC    1013.0  Found  1960
# 24154                Midland  16633    Valid       UN      34.0  Found  1960
# 38131               Um Habib  24111    Valid       OC     696.0  Found  1960
# ...                      ...    ...      ...      ...       ...    ...   ...
# 30839  Northwest Africa 7856  57421    Valid       OC     517.0  Found  2013
# 30840  Northwest Africa 7857  57422    Valid       OC     246.0  Found  2013
# 30843  Northwest Africa 7861  57425    Valid       OC     611.0  Found  2013
# 30845  Northwest Africa 7863  57427    Valid       OC    1000.0  Found  2013
# 30841  Northwest Africa 7858  57423    Valid       OC     459.0  Found  2013
#
#          reclat   reclong
# 3475   21.25417  55.30500
# 934    27.13333  84.06667
# 38215  32.40000 -97.08333
# 24154  44.75000 -79.88333
# 38131  21.50000  50.50000
# ...         ...       ...
# 30839   0.00000   0.00000
# 30840   0.00000   0.00000
# 30843   0.00000   0.00000
# 30845   0.00000   0.00000
# 30841   0.00000   0.00000
#
# [36277 rows x 9 columns]

# %%
new_era_df_2 = new_era_df.loc[(new_era_df["mass (g)"] > 0)]
new_era_df_2
# Out:
#                         name     id nametype recclass  mass (g)   fall  year  \
# 3475             as-Su'aydan   2354    Valid       OC    5855.0  Found  1960
# 934                  Soheria  23660    Valid       OC      72.9   Fell  1960
# 38215                  Venus  24160    Valid       OC    1013.0  Found  1960
# 24154                Midland  16633    Valid       UN      34.0  Found  1960
# 38131               Um Habib  24111    Valid       OC     696.0  Found  1960
# ...                      ...    ...      ...      ...       ...    ...   ...
# 30839  Northwest Africa 7856  57421    Valid       OC     517.0  Found  2013
# 30840  Northwest Africa 7857  57422    Valid       OC     246.0  Found  2013
# 30843  Northwest Africa 7861  57425    Valid       OC     611.0  Found  2013
# 30845  Northwest Africa 7863  57427    Valid       OC    1000.0  Found  2013
# 30841  Northwest Africa 7858  57423    Valid       OC     459.0  Found  2013
#
#          reclat   reclong
# 3475   21.25417  55.30500
# 934    27.13333  84.06667
# 38215  32.40000 -97.08333
# 24154  44.75000 -79.88333
# 38131  21.50000  50.50000
# ...         ...       ...
# 30839   0.00000   0.00000
# 30840   0.00000   0.00000
# 30843   0.00000   0.00000
# 30845   0.00000   0.00000
# 30841   0.00000   0.00000
#
# [36258 rows x 9 columns]

# %%
new_era_df_2["mass (Kg)"] = new_era_df_2["mass (g)"] / 1000
new_era_df_3 = new_era_df_2.drop(columns = ["mass (g)"])

new_era_df_3
# Out:
# C:\Users\thord\anaconda3\envs\Pythondata\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                         name     id nametype recclass   fall  year    reclat  \
# 3475             as-Su'aydan   2354    Valid       OC  Found  1960  21.25417
# 934                  Soheria  23660    Valid       OC   Fell  1960  27.13333
# 38215                  Venus  24160    Valid       OC  Found  1960  32.40000
# 24154                Midland  16633    Valid       UN  Found  1960  44.75000
# 38131               Um Habib  24111    Valid       OC  Found  1960  21.50000
# ...                      ...    ...      ...      ...    ...   ...       ...
# 30839  Northwest Africa 7856  57421    Valid       OC  Found  2013   0.00000
# 30840  Northwest Africa 7857  57422    Valid       OC  Found  2013   0.00000
# 30843  Northwest Africa 7861  57425    Valid       OC  Found  2013   0.00000
# 30845  Northwest Africa 7863  57427    Valid       OC  Found  2013   0.00000
# 30841  Northwest Africa 7858  57423    Valid       OC  Found  2013   0.00000
#
#         reclong  mass (Kg)
# 3475   55.30500     5.8550
# 934    84.06667     0.0729
# 38215 -97.08333     1.0130
# 24154 -79.88333     0.0340
# 38131  50.50000     0.6960
# ...         ...        ...
# 30839   0.00000     0.5170
# 30840   0.00000     0.2460
# 30843   0.00000     0.6110
# 30845   0.00000     1.0000
# 30841   0.00000     0.4590
#
# [36258 rows x 9 columns]

# %%
#Export clean data for analysis
# new_era_df_3.to_csv('cleaned_meteorite.csv', index=False)
